# %% [markdown]
# # Visualize data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
events = pd.read_csv('../data/events_file_ordered.csv')
events
# Out:
#      starting_point  peak_point  finger
# 0             23901       24220       1
# 1             24854       25219       1
# 2             25697       26094       1
# 3             36253       36575       1
# 4             37254       37617       1
# ..              ...         ...     ...
# 627          394639      395063       5
# 628          395500      395824       5
# 629          397919      398360       5
# 630          401497      401900       5
# 631          401959      402142       5
#
# [632 rows x 3 columns]

# %%
brain_data = pd.read_csv('../data/brain_data_channel_one.csv')
brain_data
# Out:
#         1.004000000000000000e+03
# 0                          663.0
# 1                          376.0
# 2                          190.0
# 3                           52.0
# 4                         -140.0
# ...                          ...
# 465834                     363.0
# 465835                     -75.0
# 465836                    -416.0
# 465837                    -412.0
# 465838                     -13.0
#
# [465839 rows x 1 columns]

# %%
len(events), len(brain_data)
# Out:
# (632, 465839)

# %%
print(events['starting_point'].min())
print(events['peak_point'].max())
# Out:
# 10770
# 459582

# %%
events.groupby('finger').size().plot(kind='bar')
plt.show()
